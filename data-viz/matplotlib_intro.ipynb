# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5,100)

# %%
# using object oriented -way
e = 2.718280
fig, ax = plt.subplots()
ax.plot(x, 1/(1+e**(-x)))
ax.plot(x, 1/(1+e**(x)))
